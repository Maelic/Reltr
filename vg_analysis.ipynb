# %% [markdown]
# ## Importing Stuff

# %%
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from IPython.display import display # to display images

import time
import numpy as np
from models import build_model
from argparse import Namespace
import os
from typing import Any, Callable, Union

vg_path = "/home/maelic/Documents/PhD/Datasets/VisualGenome"
vg_img_path = os.path.join(vg_path, "images")

# %%
img_number=2
img_path = os.path.join(vg_img_path, str(img_number) + ".jpg")
pil_im = Image.open(img_path)
display(pil_im)
#imshow(np.asarray(pil_im))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600>
